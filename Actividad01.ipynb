# %% [markdown]
# <h1>Entrega Actividad 1 – Juan Carlos López Borda</h1>

# %% [markdown]
# <h3><b>DataSet1 - Conjunto de datos lista de juegos y características plataforma Steam - (All_Steam_Games_DataSet)</b></h3>

# %%
# Pandas
import pandas as pd
url1="https://media.githubusercontent.com/media/JuanC-Pythonista/Actividad_1-Eleccion_de_Potenciales_DataSets/main/DataSetUnidad1/All_Steam_Games_DataSet.csv"
DataSet1=pd.read_csv(url1,sep=';')
# Out:
# C:\Users\jlope\AppData\Local\Temp\ipykernel_5932\279082879.py:4: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   DataSet1=pd.read_csv(url1,sep=';')

# %%
pd.set_option('display.max_columns', None)
DataSet1.head()
# Out:
#     App ID                         Name  \
# 0       10               Counter-Strike
# 1  1000000                    ASCENXION
# 2  1000010                  Crown Trick
# 3  1000030  Cook, Serve, Delicious! 3?!
# 4  1000040                         细胞战争
#
#                                    Short Description               Developer  \
# 0  Play the world's number 1 online action game. ...                   Valve
# 1  ASCENXION is a 2D shoot 'em up game where you ...  IndigoBlue Game Studio
# 2  Enter a labyrinth that moves as you move, wher...            NEXT Studios
# 3  Cook, serve and manage your food truck as you ...     Vertigo Gaming Inc.
# 4  这是一款打击感十足的细胞主题游戏！操作简单但活下去却不简单，“你”作为侵入人体的细菌病毒，通...           DoubleC Games
#
#                   Publisher                                Genre  \
# 0                     Valve                               Action
# 1  PsychoFlux Entertainment             Action, Adventure, Indie
# ...

# %%
DataSet1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55691 entries, 0 to 55690
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   App ID             55691 non-null  int64
#  1   Name               55691 non-null  object
#  2   Short Description  55654 non-null  object
#  3   Developer          55562 non-null  object
#  4   Publisher          55540 non-null  object
#  5   Genre              55530 non-null  object
#  6   Tags               55556 non-null  object
#  7   Type               55691 non-null  object
#  8   Categories         54721 non-null  object
#  9   Owners             55691 non-null  object
#  10  Positive Reviews   55691 non-null  int64
#  11  Negative Reviews   55691 non-null  int64
#  12  Price              55691 non-null  int64
#  13  Initial Price      55691 non-null  int64
#  14  Discount           55691 non-null  int64
#  15  CCU                55691 non-null  int64
# ...

# %% [markdown]
# <h5><u>DataSet1: Variables Potencialmente Interesantes</u></h5>
# <p class="text-justify">
# Objetivo: predicciones para desarrolladores de videojuegos plataforma STEAM <br><br>
# Con respecto al DataSet1 (Juegos Plataforma Steam) a mi consideración las variables importantes son:<br><br>
# •	<b>Developer:</b> La variable desarrollador es de importancia puesto que evidencia cuales empresas de desarrollo han tenido más éxito.<br>
# •	<b>Genre:</b> La variable genero evidencia que cual es el genero mas buscado por los Gamers.<br>
# •	<b>Positive Reviews:</b> La cantidad de reseñas positivas evidencian la aceptación del videojuego.<br>
# •	<b>Negative Reviews:</b> La cantidad de reseñas negativas evidencian la negación al videojuego.<br>
# •	<b>CCU (Concurrent Steam Users):</b> La concurrencia de los usuarios Steam frente al video juego demuestra la cantidad de aficionados que posee.<br>
# •	<b>Owners:</b> La variable propietarios demuestra la cantidad de usuarios que han comprado el videojuego.
# </p>

# %% [markdown]
# <h3><b>DataSet2 - Conjunto de datos desarrolladores de Estados Unidos información profesional - (Software_Developer_United_States)</b></h3>

# %%
url2="https://media.githubusercontent.com/media/JuanC-Pythonista/Actividad_1-Eleccion_de_Potenciales_DataSets/main/DataSetUnidad1/Software_Developer_United_States.csv"
DataSet2=pd.read_csv(url2,sep=',')

# %%
DataSet2.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\jlope\OneDrive\Documentos\Data Science\Workspace Data Science (Python)\Bootcamp_Data_Science_IBERO_BIT\Unidades\Unidad_1\Entrega_01\Actividad01.ipynb Cell 9 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jlope/OneDrive/Documentos/Data%20Science/Workspace%20Data%20Science%20%28Python%29/Bootcamp_Data_Science_IBERO_BIT/Unidades/Unidad_1/Entrega_01/Actividad01.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> DataSet2.head(20)
#
# NameError: name 'DataSet2' is not defined

# %%
DataSet2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   crawl_timestamp       10000 non-null  object
#  1   url                   10000 non-null  object
#  2   job_title             10000 non-null  object
#  3   category              9161 non-null   object
#  4   company_name          10000 non-null  object
#  5   city                  9869 non-null   object
#  6   state                 8754 non-null   object
#  7   country               10000 non-null  object
#  8   inferred_city         7829 non-null   object
#  9   inferred_state        9207 non-null   object
#  10  inferred_country      9229 non-null   object
#  11  post_date             10000 non-null  object
#  12  job_description       10000 non-null  object
#  13  job_type              10000 non-null  object
#  14  salary_offered        0 non-null      float64
# ...

# %% [markdown]
# <h5><u>DataSet2: Variables Potencialmente Interesantes</u></h5>

# %% [markdown]
# <h3><b>DataSet3 - Conjunto de datos encuesta StackOverflow Usuarios 2022 -(StackOverflow_Annual_Developer_Survey2022)</b></h3>

# %%
url3="https://media.githubusercontent.com/media/JuanC-Pythonista/Actividad_1-Eleccion_de_Potenciales_DataSets/main/DataSetUnidad1/StackOverflow_Annual_Developer_Survey2022.csv"
DataSet3=pd.read_csv(url3,sep=',')

# %%
DataSet3.head(6)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6  I am not primarily a developer, but I write co...
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
# 5   Student, full-time                                   NaN
#
#                            CodingActivities  \
# ...

# %%
DataSet3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %% [markdown]
# <h5><u>DataSet3: Variables Potencialmente Interesantes</u></h5>
